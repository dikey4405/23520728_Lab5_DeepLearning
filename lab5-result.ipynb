# %%
# !git clone https://github.com/dikey4405/23520728_Lab5_DeepLearning.git
# Out:
# Cloning into '23520728_Lab5_DeepLearning'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 123 (delta 61), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 16.08 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !pip install pyvi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 45.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.3 MB/s eta 0:00:00
# ...

# %%
# %cd 23520728_Lab5_DeepLearning/Bai1
# Out:
# /kaggle/working/23520728_Lab5_DeepLearning/Bai1

# %%
# !python main.py
# Out:
# 11:08:34 - INFO - Using device: cuda
# 11:08:34 - INFO - Model Config: d_model=256, layers=2, heads=4
# 11:08:34 - INFO - Building Vocabulary...
# 11:08:36 - INFO - Vocab Size: 3140 tokens
# 11:08:36 - INFO - Labels (4): {'app': 0, 'cosmetic': 1, 'fashion': 2, 'mobile': 3}
# 11:08:39 - INFO - Loaded 4350 samples from /kaggle/working/23520728_Lab5_DeepLearning/ViOCD/train.json. Skipped 37 short/empty samples.
# 11:08:39 - INFO - Loaded 545 samples from /kaggle/working/23520728_Lab5_DeepLearning/ViOCD/dev.json. Skipped 3 short/empty samples.
# 11:08:39 - INFO - Initializing Transformer Model (Base)...
# 11:08:44 - INFO - Start Training...
# 11:08:51 - INFO - Epoch 1/30 | Train Loss: 1.3597 | Val Loss: 1.1269 | Acc: 0.3431 | F1: 0.2751 [BEST MODEL SAVED]
# 11:08:57 - INFO - Epoch 2/30 | Train Loss: 1.1863 | Val Loss: 1.0046 | Acc: 0.3119 | F1: 0.3025 [BEST MODEL SAVED]
# 11:09:03 - INFO - Epoch 3/30 | Train Loss: 1.1370 | Val Loss: 1.0832 | Acc: 0.4294 | F1: 0.3380 [BEST MODEL SAVED]
# ...

# %%
# %cd 23520728_Lab5_DeepLearning/Bai2
# Out:
# /kaggle/working/23520728_Lab5_DeepLearning/Bai1/23520728_Lab5_DeepLearning/Bai2

# %%
# !python main.py
# Out:
# 11:24:22 - INFO - Using device: cuda
# 11:24:22 - INFO - Building Vocabulary...
# Building vocab from: /kaggle/working/23520728_Lab5_DeepLearning/PhoNER_COVID19/train_word.json
# File /kaggle/working/23520728_Lab5_DeepLearning/PhoNER_COVID19/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Vocab size: 4741
# Num tags: 20
# 11:24:23 - INFO - Vocab Size: 4741
# 11:24:23 - INFO - Tags (20): {'B-AGE': 0, 'B-DATE': 1, 'B-GENDER': 2, 'B-JOB': 3, 'B-LOCATION': 4, 'B-NAME': 5, 'B-ORGANIZATION': 6, 'B-PATIENT_ID': 7, 'B-SYMPTOM_AND_DISEASE': 8, 'B-TRANSPORTATION': 9, 'I-AGE': 10, 'I-DATE': 11, 'I-JOB': 12, 'I-LOCATION': 13, 'I-NAME': 14, 'I-ORGANIZATION': 15, 'I-PATIENT_ID': 16, 'I-SYMPTOM_AND_DISEASE': 17, 'I-TRANSPORTATION': 18, 'O': 19, '<pad_tag>': -100}
# Loading data from: /kaggle/working/23520728_Lab5_DeepLearning/PhoNER_COVID19/train_word.json
# ...
